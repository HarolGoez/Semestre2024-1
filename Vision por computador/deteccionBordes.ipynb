# %%
import numpy as np
import pandas as pd
import cv2 as cv
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import os

# %%
ruta = os.getcwd()+'\imagesLatex'
img = io.imread(ruta + '\powerBank.jpg')
# img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
plt.imshow(img, cmap='gray')
plt.show()
img.shape
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\i'
# <>:2: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\adria\AppData\Local\Temp\ipykernel_9628\2986105907.py:1: SyntaxWarning: invalid escape sequence '\i'
#   ruta = os.getcwd()+'\imagesLatex'
# C:\Users\adria\AppData\Local\Temp\ipykernel_9628\2986105907.py:2: SyntaxWarning: invalid escape sequence '\p'
#   img = io.imread(ruta + '\powerBank.jpg')
# (3000, 4000, 3)

# %%
Max_level = 255
th1 = 170
_, seg1 = cv.threshold(img, th1, Max_level, cv.THRESH_BINARY)
print(' th = '+ str(th1))
plt.imshow(seg1, cmap='gray')
plt.show()
# Out:
#  th = 170

# %%
edges = cv.Canny(img,90,200)
print('Bordes canny')
plt.imshow(seg1, cmap='gray')
# Out:
# Bordes canny
