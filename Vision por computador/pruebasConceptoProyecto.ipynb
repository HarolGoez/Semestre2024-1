# %%
import numpy as np
import pandas as pd
import cv2 as cv
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import os

# %%
ruta_actual = os.getcwd()
ruta = os.path.join(ruta_actual, 'imagesLatex', 'database', 'algodon')

imagenes = os.listdir(ruta)
img = io.imread( ruta + '/'+imagenes[2])
# img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
plt.imshow(img, cmap='gray')
plt.show()

# %%
d = 51
img_g00 = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
plt.imshow(img_g00, cmap='gray')

# %%
th1 = 60
Max_level = 256
_, seg1 = cv.threshold(img_g00, th1, Max_level, cv.THRESH_BINARY)
print(' th = '+ str(th1))
plt.imshow(seg1, cmap='gray')
plt.show()
# Out:
#  th = 60
